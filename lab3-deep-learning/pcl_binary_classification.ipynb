# %% [markdown]
# # Point Cloud Binary Classification with PyTorch

# %% [markdown]
# Make sure you are using the `dl4cv` conda environment.

# %% [markdown]
# ## Dataset loading and visualization

# %% [markdown]
# The input X contain 100 2D points, and y are their corresponding labels (0 or 1). The goal is to train a model that can classify every point to its correct label.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.optim import Adam

dataset = np.load('data/2d_pcl_dataset.npz')
X, y = dataset['X'], dataset['y']

X0 = X[y==0] # 50 2D points have label 0
X1 = X[y==1] # 50 2D points have label 1

def plot(X0, X1, fit_param=None):
    plt.scatter(X0[:,0], X0[:,1], color='red', label=0)
    plt.scatter(X1[:,0], X1[:,1], color='blue', label=1)
    
    plt.xlim([-0.55, 0.55])
    plt.ylim([-0.35, 0.25])
    plt.legend()
    plt.show()
    plt.clf()

plot(X0, X1)

# %% [markdown]
# ## Logistic Regression for the point cloud classification task

# %% [markdown]
# Starting by filling in the `Simple2DDataset` class below. First, in the class constructore `__init__`, you will need to read the right `2d_pcl_dataset.npz` from disk.
#
# Second, in the `__getitem__`, you will need to take a single data point and its label based on its index `idx`

# %%
class Simple2DDataset(Dataset):
    def __init__(self):
        super().__init__()
        #########################################################################
        # TODO: read data from disk using np.load.
        # Data is located in the folder "data".
        # Save samples and labels to class members self.X and self.y respectively.
        # samples should be an Nx2 numpy array. Labels should be Nx1.
        #########################################################################
        dataset = np.load('data/2d_pcl_dataset.npz')

        self.X = dataset['X']
        self.y = dataset['y']
     
    def __len__(self):
        # Returns the number of samples in the dataset.
        return self.X.shape[0]

    def __getitem__(self, idx):
        #########################################################################
        # TODO: return the sample and label with index idx
        #########################################################################
        point = self.X[idx]
        label = self.y[idx]
        
        # Convert to tensor.
        return torch.from_numpy(point).float(), \
               torch.from_numpy(label[np.newaxis]).float()

# %% [markdown]
# With the complete `Simple2DDataset`, we can create a PyTorch dataloader
#
# **NOTE**: if you encounter some unexpected errors in data loading, try setting `NUM_WORKERS = 0`

# %%
BATCH_SIZE = 8
NUM_WORKERS = 0

# create the dataloader
dataset = Simple2DDataset()
train_dataloader = DataLoader(
    dataset,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    shuffle=True
)

# %% [markdown]
# Now, define your first network by filling in the `LinearClassifier` class below.
#
# Add a single linear layer `nn.Linear` inside the `nn.Sequential` call. The input is 2D, and the output should be a single value, corresponding to the probability of a given 2D point being part of cluster 0.

# %%
class LinearClassifier(nn.Module):
    def __init__(self):
        super().__init__()

        self.codename = 'linear'

        #########################################################################
        # TODO: add a single linear layer with nn.Linear, inside the `nn.Sequential` call.
        # Input is 2D.
        # Output is a single value.
        #########################################################################
        self.model = nn.Sequential(nn.Linear(2,1))
        
    def forward(self, batch):
        # Process batch using the defined model.
        x = self.model(batch)
        # Final sigmoid activation to obtain a probability between 0 and 1.
        return torch.sigmoid(x)

# %% [markdown]
# Now, you are asked to implement the training loop below

# %%
def train(net, optimizer, dataloader, epoch):
    net.train()
    loss_sum = 0
    for batch_idx, (point, label) in enumerate(dataloader):
        # First we need to zero the gradient, otherwise PyTorch would accumulate them
        optimizer.zero_grad()

        #########################################################################
        #TODO: 
        # 1. forward pass of the network to obtain the predictions given the batch
        # 2. compute the loss using F.binary_cross_entropy
        # 3. backward pass on the loss using loss.backward(), and one step 
        # of gradient descent (optimization) using optimizer.step()
        #########################################################################
        
        output = net(point)
        loss = F.binary_cross_entropy(output, label)
        loss.backward()
        optimizer.step()

        loss_sum += loss.item()
    return loss_sum

# %% [markdown]
# You can now run below to train the linear model.

# %%
NUM_EPOCHS = 100
# create the network.
net = LinearClassifier()

# create the optimizer.
optimizer = Adam(net.parameters(), lr=0.1)

best_accuracy = 0
for epoch_idx in range(NUM_EPOCHS):
    loss = train(net, optimizer, train_dataloader, epoch_idx)
    print('[Epoch %02d] Loss: %.4f' % (epoch_idx + 1, loss))
# Out:
# [Epoch 01] Loss: 8.4609
# [Epoch 02] Loss: 6.9816
# [Epoch 03] Loss: 5.9436
# [Epoch 04] Loss: 5.3653
# [Epoch 05] Loss: 4.8910
# [Epoch 06] Loss: 4.6932
# [Epoch 07] Loss: 4.5418
# [Epoch 08] Loss: 4.2707
# [Epoch 09] Loss: 4.3017
# [Epoch 10] Loss: 4.1393
# [Epoch 11] Loss: 3.9964
# [Epoch 12] Loss: 3.8750
# [Epoch 13] Loss: 3.8475
# [Epoch 14] Loss: 4.0106
# [Epoch 15] Loss: 3.7942
# [Epoch 16] Loss: 3.7956
# [Epoch 17] Loss: 3.7168
# [Epoch 18] Loss: 3.7011
# [Epoch 19] Loss: 3.7742
# [Epoch 20] Loss: 3.8178
# [Epoch 21] Loss: 3.8784
# [Epoch 22] Loss: 3.5502
# [Epoch 23] Loss: 3.7342
# [Epoch 24] Loss: 3.7064
# [Epoch 25] Loss: 3.8661
# [Epoch 26] Loss: 3.5118
# [Epoch 27] Loss: 3.5021
# [Epoch 28] Loss: 3.7462
# [Epoch 29] Loss: 3.6092
# [Epoch 30] Loss: 3.5127
# [Epoch 31] Loss: 3.5577
# [Epoch 32] Loss: 3.7218
# [Epoch 33] Loss: 3.4634
# [Epoch 34] Loss: 3.5625
# [Epoch 35] Loss: 3.5595
# [Epoch 36] Loss: 3.7340
# [Epoch 37] Loss: 3.4957
# [Epoch 38] Loss: 3.7911
# [Epoch 39] Loss: 3.6863
# [Epoch 40] Loss: 3.5718
# [Epoch 41] Loss: 3.5435
# [Epoch 42] Loss: 3.6564
# [Epoch 43] Loss: 3.5432
# [Epoch 44] Loss: 3.4541
# [Epoch 45] Loss: 3.4994
# [Epoch 46] Loss: 3.4460
# [Epoch 47] Loss: 3.4413
# [Epoch 48] Loss: 3.5504
# [Epoch 49] Loss: 3.5125
# [Epoch 50] Loss: 3.4578
# [Epoch 51] Loss: 3.4366
# [Epoch 52] Loss: 3.5816
# [Epoch 53] Loss: 3.5979
# [Epoch 54] Loss: 3.5401
# [Epoch 55] Loss: 3.4290
# [Epoch 56] Loss: 3.5273
# [Epoch 57] Loss: 3.4272
# [Epoch 58] Loss: 3.5867
# [Epoch 59] Loss: 3.5054
# [Epoch 60] Loss: 3.5299
# [Epoch 61] Loss: 3.4471
# [Epoch 62] Loss: 3.7625
# [Epoch 63] Loss: 3.5162
# [Epoch 64] Loss: 3.4424
# [Epoch 65] Loss: 3.4828
# [Epoch 66] Loss: 3.4489
# [Epoch 67] Loss: 3.7055
# [Epoch 68] Loss: 3.5128
# [Epoch 69] Loss: 3.4693
# [Epoch 70] Loss: 3.4910
# [Epoch 71] Loss: 3.4604
# [Epoch 72] Loss: 3.7644
# [Epoch 73] Loss: 3.6898
# [Epoch 74] Loss: 3.6595
# [Epoch 75] Loss: 3.4620
# [Epoch 76] Loss: 3.4676
# [Epoch 77] Loss: 3.5537
# [Epoch 78] Loss: 3.8608
# [Epoch 79] Loss: 3.7022
# [Epoch 80] Loss: 3.5707
# [Epoch 81] Loss: 3.6264
# [Epoch 82] Loss: 3.5240
# [Epoch 83] Loss: 3.5857
# [Epoch 84] Loss: 3.5510
# [Epoch 85] Loss: 3.4579
# [Epoch 86] Loss: 3.4488
# [Epoch 87] Loss: 3.5403
# [Epoch 88] Loss: 3.5039
# [Epoch 89] Loss: 3.4918
# [Epoch 90] Loss: 3.5179
# [Epoch 91] Loss: 3.5029
# [Epoch 92] Loss: 3.7860
# [Epoch 93] Loss: 3.4367
# [Epoch 94] Loss: 3.7838
# [Epoch 95] Loss: 3.4534
# [Epoch 96] Loss: 3.4501
# [Epoch 97] Loss: 3.4931
# [Epoch 98] Loss: 3.5988
# [Epoch 99] Loss: 3.5825
# [Epoch 100] Loss: 3.7143

# %% [markdown]
# Now plot your result below.

# %%
p = np.linspace(-0.5, 0.5, 500)
x_plot, y_plot = np.meshgrid(p, p)
X_plot = np.stack((x_plot, y_plot), axis=2).reshape(-1, 2)
X_plot = torch.from_numpy(X_plot).float()
output = net(X_plot)
output = output.detach().numpy()
output = output.reshape(x_plot.shape[0], x_plot.shape[1])

plt.contour(x_plot, y_plot, output, [0.5],
                  colors=('k',),
                  linewidths=(3,))
plot(X0, X1)

# %% [markdown]
# ### Implement your first multi-layer perceptron (MLP) for point cloud classification
# Now you should notice that your logistic regression model cannot classify the point cloud correctly, and this is as expected :)
# Therefore, we now ask you to implement an MLP for the same binary classification task.

# %%
# These are the parameters to be used
nInput = 2
nOutput = 1
nHidden = 16
act_fn = nn.ReLU()

class MLP(nn.Module):
    def __init__(self, nInput, nOutput, nHidden, act_fn):
        super().__init__()

        # Define the network layers in order.
        # Input is 2D (nInput).
        # Output is a single value (nOutput).
        # Multiple linear layers each followed by a ReLU non-linearity (apart from the last).
        #########################################################################
        # TODO: add a two-layer MLP, inside the `nn.Sequential` call.
        # Input is 2D.
        # Output is a single value.

        # Hint: unlike logistic regression where you need only one nn.Linear layer, 
        # here you will have two nn.Linear layers. After the first layer, we 
        # apply a ReLU activation function. The output is then passed to another 
        # linear layer. Note that you should use `nHidden` below as the hidden dimension 
        # of your linear layers.
        #########################################################################
        self.model = nn.Sequential(nn.Linear(nInput, nHidden), 
                                   act_fn, 
                                   nn.Linear(nHidden, nOutput))
        
    def forward(self, batch):
        # Process batch using the defined model.
        x = self.model(batch)
        # Final sigmoid activation to obtain a probability.
        return torch.sigmoid(x)

# %% [markdown]
# Run below again!

# %%
NUM_EPOCHS = 200

# create the network.
net = MLP(nInput, nOutput, nHidden, act_fn)

# create the optimizer.
optimizer = Adam(net.parameters(), lr=0.1)

best_accuracy = 0
for epoch_idx in range(NUM_EPOCHS):
    loss = train(net, optimizer, train_dataloader, epoch_idx)
    print('[Epoch %02d] Loss: %.4f' % (epoch_idx + 1, loss))
# Out:
# [Epoch 01] Loss: 8.3719
# [Epoch 02] Loss: 4.7956
# [Epoch 03] Loss: 3.8852
# [Epoch 04] Loss: 3.8634
# [Epoch 05] Loss: 3.5740
# [Epoch 06] Loss: 3.4527
# [Epoch 07] Loss: 3.2632
# [Epoch 08] Loss: 2.7747
# [Epoch 09] Loss: 2.7362
# [Epoch 10] Loss: 2.4115
# [Epoch 11] Loss: 2.3560
# [Epoch 12] Loss: 1.9932
# [Epoch 13] Loss: 1.9592
# [Epoch 14] Loss: 1.5223
# [Epoch 15] Loss: 1.5956
# [Epoch 16] Loss: 1.3486
# [Epoch 17] Loss: 1.1282
# [Epoch 18] Loss: 1.2217
# [Epoch 19] Loss: 1.1063
# [Epoch 20] Loss: 0.8855
# [Epoch 21] Loss: 0.9119
# [Epoch 22] Loss: 0.7291
# [Epoch 23] Loss: 0.8139
# [Epoch 24] Loss: 0.7470
# [Epoch 25] Loss: 0.6923
# [Epoch 26] Loss: 0.6717
# [Epoch 27] Loss: 0.6391
# [Epoch 28] Loss: 0.6690
# [Epoch 29] Loss: 0.5278
# [Epoch 30] Loss: 0.4265
# [Epoch 31] Loss: 0.4511
# [Epoch 32] Loss: 0.4285
# [Epoch 33] Loss: 0.4023
# [Epoch 34] Loss: 0.3665
# [Epoch 35] Loss: 0.3887
# [Epoch 36] Loss: 0.4168
# [Epoch 37] Loss: 0.4313
# [Epoch 38] Loss: 0.4293
# [Epoch 39] Loss: 0.3858
# [Epoch 40] Loss: 0.4657
# [Epoch 41] Loss: 0.3007
# [Epoch 42] Loss: 0.2862
# [Epoch 43] Loss: 0.2812
# [Epoch 44] Loss: 0.3472
# [Epoch 45] Loss: 0.2955
# [Epoch 46] Loss: 0.2551
# [Epoch 47] Loss: 0.2895
# [Epoch 48] Loss: 0.2485
# [Epoch 49] Loss: 0.2121
# [Epoch 50] Loss: 0.2666
# [Epoch 51] Loss: 0.2220
# [Epoch 52] Loss: 0.2131
# [Epoch 53] Loss: 0.2018
# [Epoch 54] Loss: 0.2418
# [Epoch 55] Loss: 0.2542
# [Epoch 56] Loss: 0.2296
# [Epoch 57] Loss: 0.3017
# [Epoch 58] Loss: 0.2796
# [Epoch 59] Loss: 0.2133
# [Epoch 60] Loss: 0.2472
# [Epoch 61] Loss: 0.2815
# [Epoch 62] Loss: 0.2543
# [Epoch 63] Loss: 0.2886
# [Epoch 64] Loss: 0.1837
# [Epoch 65] Loss: 0.1603
# [Epoch 66] Loss: 0.1629
# [Epoch 67] Loss: 0.1856
# [Epoch 68] Loss: 0.1501
# [Epoch 69] Loss: 0.1525
# [Epoch 70] Loss: 0.1833
# [Epoch 71] Loss: 0.1767
# [Epoch 72] Loss: 0.1199
# [Epoch 73] Loss: 0.1658
# [Epoch 74] Loss: 0.1248
# [Epoch 75] Loss: 0.1518
# [Epoch 76] Loss: 0.1942
# [Epoch 77] Loss: 0.2349
# [Epoch 78] Loss: 0.1890
# [Epoch 79] Loss: 0.1547
# [Epoch 80] Loss: 0.1215
# [Epoch 81] Loss: 0.1376
# [Epoch 82] Loss: 0.1107
# [Epoch 83] Loss: 0.0886
# [Epoch 84] Loss: 0.1137
# [Epoch 85] Loss: 0.1423
# [Epoch 86] Loss: 0.0995
# [Epoch 87] Loss: 0.1068
# [Epoch 88] Loss: 0.1010
# [Epoch 89] Loss: 0.1018
# [Epoch 90] Loss: 0.0998
# [Epoch 91] Loss: 0.0845
# [Epoch 92] Loss: 0.0890
# [Epoch 93] Loss: 0.1138
# [Epoch 94] Loss: 0.0996
# [Epoch 95] Loss: 0.0967
# [Epoch 96] Loss: 0.1375
# [Epoch 97] Loss: 0.1573
# [Epoch 98] Loss: 0.1315
# [Epoch 99] Loss: 0.4159
# [Epoch 100] Loss: 29.3501
# [Epoch 101] Loss: 5.0462
# [Epoch 102] Loss: 19.5793
# [Epoch 103] Loss: 76.9517
# [Epoch 104] Loss: 3.8856
# [Epoch 105] Loss: 0.8102
# [Epoch 106] Loss: 0.2123
# [Epoch 107] Loss: 0.1908
# [Epoch 108] Loss: 0.0933
# [Epoch 109] Loss: 0.0859
# [Epoch 110] Loss: 0.0709
# [Epoch 111] Loss: 0.0681
# [Epoch 112] Loss: 0.0657
# [Epoch 113] Loss: 0.0637
# [Epoch 114] Loss: 0.0626
# [Epoch 115] Loss: 0.0688
# [Epoch 116] Loss: 0.0589
# [Epoch 117] Loss: 0.0639
# [Epoch 118] Loss: 0.0654
# [Epoch 119] Loss: 0.0705
# [Epoch 120] Loss: 0.0569
# [Epoch 121] Loss: 0.0559
# [Epoch 122] Loss: 0.0572
# [Epoch 123] Loss: 0.0585
# [Epoch 124] Loss: 0.0537
# [Epoch 125] Loss: 0.0582
# [Epoch 126] Loss: 0.0571
# [Epoch 127] Loss: 0.0611
# [Epoch 128] Loss: 0.0589
# [Epoch 129] Loss: 0.0522
# [Epoch 130] Loss: 0.0511
# [Epoch 131] Loss: 0.0536
# [Epoch 132] Loss: 0.0565
# [Epoch 133] Loss: 0.0654
# [Epoch 134] Loss: 0.0530
# [Epoch 135] Loss: 0.0736
# [Epoch 136] Loss: 0.0510
# [Epoch 137] Loss: 0.0532
# [Epoch 138] Loss: 0.0462
# [Epoch 139] Loss: 0.0447
# [Epoch 140] Loss: 0.0451
# [Epoch 141] Loss: 0.0448
# [Epoch 142] Loss: 0.0443
# [Epoch 143] Loss: 0.0421
# [Epoch 144] Loss: 0.0437
# [Epoch 145] Loss: 0.0529
# [Epoch 146] Loss: 0.0476
# [Epoch 147] Loss: 0.0409
# [Epoch 148] Loss: 0.0427
# [Epoch 149] Loss: 0.0399
# [Epoch 150] Loss: 0.0445
# [Epoch 151] Loss: 0.0606
# [Epoch 152] Loss: 0.0422
# [Epoch 153] Loss: 0.0547
# [Epoch 154] Loss: 0.0412
# [Epoch 155] Loss: 0.0390
# [Epoch 156] Loss: 0.0367
# [Epoch 157] Loss: 0.0365
# [Epoch 158] Loss: 0.0365
# [Epoch 159] Loss: 0.0366
# [Epoch 160] Loss: 0.0373
# [Epoch 161] Loss: 0.0406
# [Epoch 162] Loss: 0.0346
# [Epoch 163] Loss: 0.0387
# [Epoch 164] Loss: 0.0335
# [Epoch 165] Loss: 0.0379
# [Epoch 166] Loss: 0.0331
# [Epoch 167] Loss: 0.0357
# [Epoch 168] Loss: 0.0337
# [Epoch 169] Loss: 0.0355
# [Epoch 170] Loss: 0.0305
# [Epoch 171] Loss: 0.0293
# [Epoch 172] Loss: 0.0311
# [Epoch 173] Loss: 0.0313
# [Epoch 174] Loss: 0.0287
# [Epoch 175] Loss: 0.0321
# [Epoch 176] Loss: 0.0294
# [Epoch 177] Loss: 0.0285
# [Epoch 178] Loss: 0.0271
# [Epoch 179] Loss: 0.0264
# [Epoch 180] Loss: 0.0312
# [Epoch 181] Loss: 0.0269
# [Epoch 182] Loss: 0.0297
# [Epoch 183] Loss: 0.0279
# [Epoch 184] Loss: 0.0254
# [Epoch 185] Loss: 0.0345
# [Epoch 186] Loss: 0.0256
# [Epoch 187] Loss: 0.0247
# [Epoch 188] Loss: 0.0239
# [Epoch 189] Loss: 0.0236
# [Epoch 190] Loss: 0.0234
# [Epoch 191] Loss: 0.0240
# [Epoch 192] Loss: 0.0229
# [Epoch 193] Loss: 0.0224
# [Epoch 194] Loss: 0.0220
# [Epoch 195] Loss: 0.0216
# [Epoch 196] Loss: 0.0223
# [Epoch 197] Loss: 0.0221
# [Epoch 198] Loss: 0.0214
# [Epoch 199] Loss: 0.0207
# [Epoch 200] Loss: 0.0231

# %% [markdown]
# Again plot your result. You should see that the decision boundary can clearly separate the point clouds.

# %%
p = np.linspace(-0.5, 0.5, 500)
x_plot, y_plot = np.meshgrid(p, p)
X_plot = np.stack((x_plot, y_plot), axis=2).reshape(-1, 2)
X_plot = torch.from_numpy(X_plot).float()
output = net(X_plot)
output = output.detach().numpy()
output = output.reshape(x_plot.shape[0], x_plot.shape[1])

plt.contour(x_plot, y_plot, output, [0.5],
                  colors=('k',),
                  linewidths=(3,))
plot(X0, X1)

# %% [markdown]
# When you are done, move forward to `image_classification.ipynb`.
